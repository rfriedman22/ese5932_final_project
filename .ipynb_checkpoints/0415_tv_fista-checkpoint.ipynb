# %%
import numpy as np
import scipy.io
import os
import matplotlib.pyplot as plt
# pyunlocbox
from pyunlocbox import functions
from pyunlocbox import solvers

# %%
proj_data = scipy.io.loadmat(os.path.join("data", "project_data.mat"))
#A90 = scipy.io.loadmat('data/A90.mat')
#A90 = A90['A']
#A270 = scipy.io.loadmat('data/A90.mat')
Afull = scipy.io.loadmat('../A.mat')
Afull = Afull['A']
#sino90 = scipy.io.loadmat('data/Sinogram90.mat')
#sino90 = sino90['sinogram90']
sinofull = proj_data['sinogram']
sinofull_flat = np.transpose(sinofull.flatten(order = 'F'))
#sino90_flat = np.transpose(sino90.flatten(order = 'F'))

# %% [markdown]
# We can formulate the reconstrucion from the sinogram as an optimization problem as following:
# $$
# min_x ||A(x) - b||^2 + 2 \lambda ||x||_{TV}
# $$
# The formulation of the optimization problem follows the theoretical framework layed out in citation. First we consider the sinogram data. Let $b \in \mathbb{R}^{mxn}$ be the measured sinogram, where $n$ is the number of x-ray sources and $m$ is the number of angles. $x \in \mathbb{R}^{256^2 X 1}$ be the flattened true image with the resolution of 256X256. A is an affine map representing an operator and $\eta$ is a corresponding additive nuknown noise satistifying the additive relation (expand on the sources of noise).

# %%
tau = 1
f1 = functions.norm_tv(maxit=50, dim=1)
n_pixels = np.product(proj_data["imgref"].shape)
f2 = functions.norm_l2(y=sinofull_flat, A=Afull,lambda_=tau)
solver = solvers.forward_backward(step=0.5/tau)
#solver = solvers.douglas_rachford(step=0.1)
model_init = np.zeros(n_pixels)
ret = solvers.solve([f1, f2], model_init, solver, rtol = 1e-5, maxit=1000)
# Out:
# Solution found after 169 iterations:
#     objective function f(sol) = 3.084675e+04
#     stopping criterion: RTOL

# %%
model_mat = ret['sol'].reshape(proj_data["imgref"].shape, order="F")
fig, ax = plt.subplots(ncols=2, figsize = (18,12))
ax[0].imshow(proj_data["imgref"], cmap="gray")
ax[0].set_title("Reference")
ax[1].imshow(model_mat, cmap="gray")
ax[1].set_title(f"Reconstruction, beta = {round(1/tau, 3)}")
plt.savefig('TV_reconstruction.png', dpi = 300)

# %% [markdown]
# ## Regularization parameter search
#
# It is a little difficult to implement a L curve, because it is not obvious how to get the misfit from the black box code.
#
# But the soft start idea is implementable.

# %%
lambdas = [1, 10,100,1000]
n_pixels = np.product(proj_data["imgref"].shape)
# Initiate a dict to hold the final results
model_init = np.zeros(n_pixels)
stuff = []
for lamb in lambdas:
    f1 = functions.norm_tv(maxit=50, dim=1) 
    # Construct the second convex function
    f2 = functions.norm_l2(y=sinofull_flat, A=Afull,lambda_=lamb)
    # FISTA 
    solver = solvers.forward_backward(step=0.5/lamb)
    ret = solvers.solve([f1, f2], model_init, solver, rtol = 1e-5, maxit=2)
    model_init = ret['sol']
    print('model is', model_init)
    stuff.append(model_init)
stuff
# Out:
# Solution found after 2 iterations:
#     objective function f(sol) = 4.363356e+05
#     stopping criterion: MAXIT
# model is [0.33454095 0.33456951 0.33462649 ... 0.32434169 0.32429983 0.32427885]
# Solution found after 2 iterations:
#     objective function f(sol) = 4.117935e+06
#     stopping criterion: MAXIT
# model is [0.65195718 0.65215755 0.65254158 ... 0.63289487 0.63257391 0.63241608]
# Solution found after 2 iterations:
#     objective function f(sol) = 3.889638e+07
#     stopping criterion: MAXIT
# model is [0.95560139 0.95588719 0.95660602 ... 0.92809422 0.92747498 0.92726882]
# Solution found after 2 iterations:
#     objective function f(sol) = 3.676376e+08
#     stopping criterion: MAXIT
# model is [1.24615227 1.24657782 1.2473328  ... 1.21048506 1.20982004 1.20944839]
# [array([1.24615227, 1.24657782, 1.2473328 , ..., 1.21048506, 1.20982004,
#         1.20944839]),
#  array([1.24615227, 1.24657782, 1.2473328 , ..., 1.21048506, 1.20982004,
#         1.20944839]),
#  array([1.24615227, 1.24657782, 1.2473328 , ..., 1.21048506, 1.20982004,
#         1.20944839]),
#  array([1.24615227, 1.24657782, 1.2473328 , ..., 1.21048506, 1.20982004,
#         1.20944839])]

# %%
fig, axs = plt.subplots(ncols=2, nrows =2, figsize = (12,18))
axs = axs.ravel()
axs[0].imshow(proj_data["imgref"], cmap="gray")
axs[0].set_title("Reference")
for i, lamb in enumerate(lambdas):
    model_mat = stuff[i].reshape(proj_data["imgref"].shape, order="F")
    axs[i+1].imshow(model_mat, cmap="gray")
    axs[i+1].set_title(f"Reconstruction, beta = {round(1/lamb, 3)}")
#plt.savefig('TV_reconstruction.png', dpi = 300)
